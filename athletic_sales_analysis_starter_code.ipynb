# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020 = pd.read_csv("Resources/athletic_sales_2020.csv")
athletic_sales_2021 = pd.read_csv("Resources/athletic_sales_2021.csv")

# %%
# Display the 2020 sales DataFrame
athletic_sales_2020
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
athletic_sales_2021
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
print(athletic_sales_2020.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
print(athletic_sales_2021.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
athletic_sales_both = pd.concat([athletic_sales_2020,athletic_sales_2021],ignore_index = True)

# Directions say to use an inner join with an index reset, but I think this
# concat function is what is really being asked for.

#also check to make sure this worked:
athletic_sales_both
# Out:
#           retailer_x  retailer_id invoice_date_x   region_x    state_x  \
# 0        Foot Locker      1185732         1/1/20  Northeast   New York
# 1        Foot Locker      1185732         1/1/20  Northeast   New York
# 2        Foot Locker      1185732         1/1/20  Northeast   New York
# 3        Foot Locker      1185732         1/1/20  Northeast   New York
# 4        Foot Locker      1185732         1/1/20  Northeast   New York
# ...              ...          ...            ...        ...        ...
# 3710109       Kohl's      1189833       12/30/20    Midwest  Minnesota
# 3710110       Kohl's      1189833       12/30/20    Midwest  Minnesota
# 3710111       Kohl's      1189833       12/30/20    Midwest  Minnesota
# 3710112       Kohl's      1189833       12/30/20    Midwest  Minnesota
# 3710113       Kohl's      1189833       12/30/20    Midwest  Minnesota
#
#               city_x                product_x  price_per_unit_x  units_sold_x  \
# ...

# %%
# Check if any values are null.
print(athletic_sales_both.isnull().any())
# Out:
# retailer            False
# retailer_id         False
# invoice_date        False
# region              False
# state               False
# city                False
# product             False
# price_per_unit      False
# units_sold          False
# total_sales         False
# operating_profit    False
# sales_method        False
# dtype: bool

# %%
# Check the data type of each column
print(athletic_sales_both.dtypes)
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
athletic_sales_both["invoice_date"] = athletic_sales_both["invoice_date"].apply(pd.to_datetime)

# %%
# Confirm that the "invoice_date" data type has been changed.
print(athletic_sales_both.dtypes)
# Out:
# retailer                    object
# retailer_id                  int64
# invoice_date        datetime64[ns]
# region                      object
# state                       object
# city                        object
# product                     object
# price_per_unit               int64
# units_sold                   int64
# total_sales                  int64
# operating_profit           float64
# sales_method                object
# dtype: object

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
# Rename the sum to "Total_Products_Sold".

grouped_athletic_sales = (athletic_sales_both.groupby(
    ["region","state","city"])["units_sold"].sum()
    .reset_index(name='Total_Products_Sold'))


# Show the top 5 results.
sorted_athletic_sales = grouped_athletic_sales.sort_values("Total_Products_Sold",
                                                           ascending=False)
sorted_athletic_sales.head()
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_table = pd.pivot_table(athletic_sales_both, index=['region', 'state', 'city']
                             , values='units_sold', aggfunc='sum')


# Rename the "units_sold" column to "Total_Products_Sold"
pivot_table = pivot_table.rename(columns = {'units_sold': 'Total_Products_Sold'})
# Show the top 5 results.
sorted_pivot_table = pivot_table.sort_values('Total_Products_Sold',ascending = False)
sorted_pivot_table.head()
# Out:
#                                     Total_Products_Sold
# region    state      city
# Northeast New York   New York                    111954
# South     Texas      Houston                      90322
# West      California San Francisco                85478
#                      Los Angeles                  76384
# Southeast Florida    Miami                        73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
# Rename the "total_sales" column to "Total Sales"

grouped_athletic_sales2 = (athletic_sales_both.groupby(
    ["region","state","city"])["total_sales"].sum()
    .reset_index(name='Total Sales'))


# Show the top 5 results.
sorted_athletic_sales2 = grouped_athletic_sales2.sort_values("Total Sales",
                                                             ascending=False)
sorted_athletic_sales2.head()
# Out:
#        region           state           city  Total Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.

pivot_table2 = pd.pivot_table(athletic_sales_both, index=['region', 'state', 'city']
                             , values='total_sales', aggfunc='sum')


pivot_table2 = pivot_table2.rename(columns = {'total_sales': 'Total Sales'})
# Show the top 5 results.
sorted_pivot_table2 = pivot_table2.sort_values('Total Sales',ascending = False)
sorted_pivot_table2.head()
# Out:
#                                         Total Sales
# region    state          city
# Northeast New York       New York          39801235
# West      California     San Francisco     33973228
# Southeast Florida        Miami             31600863
#           South Carolina Charleston        29285637
#           Florida        Orlando           27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
# Rename the "total_sales" column to "Total Sales"
grouped_athletic_sales3 = (athletic_sales_both.groupby(
    ["retailer","region","state","city"])["total_sales"].sum()
    .reset_index(name='Total Sales'))


# Show the top 5 results.
sorted_athletic_sales3 = grouped_athletic_sales3.sort_values("Total Sales",
                                                             ascending=False)
sorted_athletic_sales3.head()
# Out:
#         retailer     region           state           city  Total Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_table3 = pd.pivot_table(athletic_sales_both, index=['retailer','region', 'state', 'city']
                             , values='total_sales', aggfunc='sum')

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_table3 = pivot_table3.rename(columns = {'total_sales': 'Total Sales'})

# Show the top 5 results.
sorted_pivot_table3 = pivot_table3.sort_values('Total Sales',ascending = False)
sorted_pivot_table3.head()
# Out:
#                                                     Total Sales
# retailer    region    state          city
# West Gear   West      California     San Francisco     32794405
# Kohl's      West      California     Los Angeles       25127160
# Foot Locker Northeast New York       New York          25008568
# West Gear   West      Washington     Seattle           24862675
# Foot Locker Southeast South Carolina Charleston        24822280

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
athletic_sales_women_shoes = (athletic_sales_both[athletic_sales_both['product']
                                                  == "Women's Street Footwear"])
athletic_sales_women_shoes
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 14    Foot Locker      1185732   2020-01-03  Northeast      New York
# 15    Foot Locker      1185732   2020-01-03  Northeast      New York
# 17    Foot Locker      1185732   2020-01-03  Northeast      New York
# 18      West Gear      1128299   2020-01-04  Northeast  Pennsylvania
# 19      West Gear      1128299   2020-01-04  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9628  Foot Locker      1185732   2021-12-29  Northeast  Pennsylvania
# 9629       Amazon      1185732   2021-12-29  Northeast         Maine
# 9630  Foot Locker      1185732   2021-12-29  Northeast  Pennsylvania
# 9631       Amazon      1185732   2021-12-29  Northeast         Maine
# 9632  Foot Locker      1185732   2021-12-29  Northeast  Pennsylvania
#
#               city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
athletic_sales_women_shoes_grouped = athletic_sales_women_shoes.groupby([
    "retailer","region","state","city"])["units_sold"].sum().reset_index(name =
    "Womens_Footwear_Units_Sold")
# Show the top 5 results.
athletic_sales_women_shoes_grouped = athletic_sales_women_shoes_grouped.sort_values(
    "Womens_Footwear_Units_Sold",ascending = False)
athletic_sales_women_shoes_grouped.head()
# Out:
#           retailer     region       state           city  \
# 103      West Gear       West  California  San Francisco
# 22     Foot Locker  Northeast    New York       New York
# 50          Kohl's       West  California    Los Angeles
# 69   Sports Direct      South       Texas         Dallas
# 83         Walmart      South       Texas        Houston
#
#      Womens_Footwear_Units_Sold
# 103                       13346
# 22                        12088
# 50                        12030
# 69                        11863
# 83                        11457

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
women_shoe_pivot = pd.pivot_table(athletic_sales_women_shoes, index = [
    "retailer", "region", "state","city"],values = "units_sold",aggfunc = "sum")

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
women_shoe_pivot = women_shoe_pivot.rename(columns = {"units_sold" : "Womens_Footwear_Units_Sold"})
# Show the top 5 results.
women_shoe_pivot = women_shoe_pivot.sort_values("Womens_Footwear_Units_Sold", ascending = False)
women_shoe_pivot.head()
# Out:
#                                                   Womens_Footwear_Units_Sold
# retailer      region    state      city
# West Gear     West      California San Francisco                       13346
# Foot Locker   Northeast New York   New York                            12088
# Kohl's        West      California Los Angeles                         12030
# Sports Direct South     Texas      Dallas                              11863
# Walmart       South     Texas      Houston                             11457

# %% [markdown]
# ### 5. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
women_shoes_sales_date_pivot = pd.pivot_table(athletic_sales_women_shoes
                                              , index = "invoice_date"
                                              , values = "total_sales"
                                              , aggfunc = "sum")

# Optional: Rename the "total_sales" column to "Total Sales"
women_shoes_sales_date_pivot = women_shoes_sales_date_pivot.rename(columns = {"total_sales":"Total Sales"})

# Show the table.
women_shoes_sales_date_pivot
# Out:
#               Total Sales
# invoice_date
# 2020-01-03         420200
# 2020-01-04         212337
# 2020-01-10         200469
# 2020-01-16         230912
# 2020-01-21         400272
# ...                   ...
# 2021-12-21         155024
# 2021-12-22         201299
# 2021-12-23        1036085
# 2021-12-25         314270
# 2021-12-29         211109
#
# [363 rows x 1 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_pivot = women_shoes_sales_date_pivot.resample('D').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
daily_pivot = daily_pivot.sort_values("Total Sales",ascending = True)
daily_pivot

# the directions say to sort in ascending order, but also to show the top 10,
# so it was probably meant to say that we should sort in descending order.
# because of that, I will do that here also:

daily_pivot = daily_pivot.sort_values("Total Sales",ascending = False)
daily_pivot
# Out:
#               Total Sales
# invoice_date
# 2021-07-16        1853760
# 2021-06-17        1610310
# 2021-08-17        1537629
# 2021-12-16        1532937
# 2021-07-23        1227152
# ...                   ...
# 2020-01-25              0
# 2020-01-24              0
# 2020-01-23              0
# 2021-12-24              0
# 2021-10-28              0
#
# [727 rows x 1 columns]

# %% [markdown]
# ### 6.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_pivot = women_shoes_sales_date_pivot.resample('W').sum()

# Sort the resampled pivot table in ascending order on "Total Sales".
weekly_pivot = weekly_pivot.sort_values("Total Sales",ascending = False)
weekly_pivot
# Out:
#               Total Sales
# invoice_date
# 2021-07-11        3413832
# 2021-12-19        3397051
# 2021-07-18        3356485
# 2021-08-22        3237784
# 2021-08-15        3155382
# ...                   ...
# 2020-11-29          92268
# 2020-11-22          62801
# 2020-12-20          59368
# 2020-12-13          35800
# 2020-10-18              0
#
# [105 rows x 1 columns]
